# %% [markdown]
# # O único curso que te ensina a habilidade mais procurada por recrutadores de Data Science: CursoDeDataScience.com

# %% [markdown]
# ## Esta live não é recomendação médica. Eu não entendo da área de saúde. Siga o que eu falo de DS, não de saúde.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
pd.set_option("display.max_columns", 111)

# %%
data = pd.read_excel('dataset.xlsx')
data['SARS-Cov-2 exam result'] = data['SARS-Cov-2 exam result'].map(dict(negative=0, positive=1))

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13                       0
# 1  126e9dd13932f68                    17                       0
# 2  a46b4402a0e5696                     8                       0
# 3  f7d619a94f97c45                     5                       0
# 4  d9e41465789c2b5                    15                       0
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# ...

# %%
data_nan = data.isnull().astype(int)
data_nan['SARS-Cov-2 exam result'] = data['SARS-Cov-2 exam result']

# %%
c = data_nan.corr(method='spearman')['SARS-Cov-2 exam result'].sort_values()
c
# Out:
# ctO2 (arterial blood gas analysis)                      -0.088874
# Arterial Lactic Acid                                    -0.088874
# Hb saturation (arterial blood gases)                    -0.088874
# pCO2 (arterial blood gas analysis)                      -0.088874
# Base excess (arterial blood gas analysis)               -0.088874
# Total CO2 (arterial blood gas analysis)                 -0.088874
# HCO3 (arterial blood gas analysis)                      -0.088874
# pO2 (arterial blood gas analysis)                       -0.088874
# pH (arterial blood gas analysis)                        -0.088874
# Total Bilirubin                                         -0.073947
# Direct Bilirubin                                        -0.073947
# Indirect Bilirubin                                      -0.073947
# Lactic Dehydrogenase                                    -0.071707
# Arteiral Fio2                                           -0.070153
# ...

# %% [markdown]
# - simples fato de ser não-nulo possui informação, não é nulo at random

# %%
sick = data[data['SARS-Cov-2 exam result'] == 1]

# %%
data.isnull().mean().sort_values()
# Out:
# Patient ID                                               0.000000
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Influenza B                                              0.760099
# Respiratory Syncytial Virus                              0.760099
# Influenza A                                              0.760099
# Rhinovirus/Enterovirus                                   0.760454
# Inf A H1N1 2009                                          0.760454
# CoronavirusOC43                                          0.760454
# Coronavirus229E                                          0.760454
# Parainfluenza 4                                          0.760454
# ...

# %%
data[data['Patient addmited to intensitve unit ward (1=yes, 0=no)'] == 0]['SARS-Cov-2 exam result'].mean()
# Out:
# 0.09380053908355795

# %%
sick
# Out:
#            Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 67    78511c183ae18bc                     7                       1
# 284   d7834ed75f2da44                    16                       1
# 513   b16b49f7bd3e692                    10                       1
# 568   4382f5ea05e60c4                     2                       1
# 676   d3729cd2658ca64                    15                       1
# 884   ab9745da9d139b9                    15                       1
# 1011  a0435dd40e745fd                     7                       1
# 1108  9d7c293a6773d6a                    14                       1
# 1113  ff5ec3abd7d6088                     5                       1
# 1129  7b1d6bf5993aa9b                     9                       1
# 1156  1e7e33688edc5a9                    11                       1
# 1162  2a5db9bbb45109f                    14                       1
# 1168  3fc734fd9bafbd6                    18                       1
# ...
