# %%
import pandas as pd
import numpy as np
# %matplotlib inline
pd.set_option("display.max_columns", 111)
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, roc_auc_score

from category_encoders import OneHotEncoder

import tensorflow.keras as tfk

import autogluon as ag
from autogluon import TabularPrediction as task

# %%
data = pd.read_excel('dataset.xlsx')
data['SARS-Cov-2 exam result'] = data['SARS-Cov-2 exam result'].map(dict(negative=0, positive=1))
data.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in data.columns]
data['Urine___pH'] = data['Urine___pH'].map(lambda x: -100 if isinstance(x, str) else x).astype(float)
data['Urine___Leukocytes'] = data['Urine___Leukocytes'].map(lambda x: 500 if x == '<1000' else x).astype(float)
data['admitted'] = data[['Patient_addmited_to_regular_ward__1_yes__0_no_', 
                         'Patient_addmited_to_semi_intensive_unit__1_yes__0_no_', 
                         'Patient_addmited_to_intensive_care_unit__1_yes__0_no_']].max(axis=1)

# %%
data.head()
# Out:
#         Patient_ID  Patient_age_quantile  SARS_Cov_2_exam_result  \
# 0  44477f75e8169d2                    13                       0
# 1  126e9dd13932f68                    17                       0
# 2  a46b4402a0e5696                     8                       0
# 3  f7d619a94f97c45                     5                       0
# 4  d9e41465789c2b5                    15                       0
#
#    Patient_addmited_to_regular_ward__1_yes__0_no_  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient_addmited_to_semi_intensive_unit__1_yes__0_no_  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Patient_addmited_to_intensive_care_unit__1_yes__0_no_  Hematocrit  \
# 0                                                  0             NaN
# 1                                                  0        0.236515
# 2                                                  0             NaN
# 3                                                  0             NaN
# 4                                                  0             NaN
#
#    Hemoglobin  Platelets  Mean_platelet_volume_  Red_blood_Cells  Lymphocytes  \
# 0         NaN        NaN                    NaN              NaN          NaN
# 1    -0.02234  -0.517413               0.010677         0.102004     0.318366
# 2         NaN        NaN                    NaN              NaN          NaN
# 3         NaN        NaN                    NaN              NaN          NaN
# 4         NaN        NaN                    NaN              NaN          NaN
#
#    Mean_corpuscular_hemoglobin_concentration__MCHC_  Leukocytes  Basophils  \
# 0                                               NaN         NaN        NaN
# 1                                          -0.95079    -0.09461  -0.223767
# 2                                               NaN         NaN        NaN
# 3                                               NaN         NaN        NaN
# 4                                               NaN         NaN        NaN
#
#    Mean_corpuscular_hemoglobin__MCH_  Eosinophils  \
# 0                                NaN          NaN
# 1                          -0.292269     1.482158
# 2                                NaN          NaN
# 3                                NaN          NaN
# 4                                NaN          NaN
#
#    Mean_corpuscular_volume__MCV_  Monocytes  \
# 0                            NaN        NaN
# 1                       0.166192   0.357547
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
#
#    Red_blood_cell_distribution_width__RDW_  Serum_Glucose  \
# 0                                      NaN            NaN
# 1                                -0.625073      -0.140648
# 2                                      NaN            NaN
# 3                                      NaN            NaN
# 4                                      NaN            NaN
#
#   Respiratory_Syncytial_Virus   Influenza_A   Influenza_B Parainfluenza_1  \
# 0                         NaN           NaN           NaN             NaN
# 1                not_detected  not_detected  not_detected    not_detected
# 2                         NaN           NaN           NaN             NaN
# 3                         NaN           NaN           NaN             NaN
# 4                not_detected  not_detected  not_detected    not_detected
#
#   CoronavirusNL63 Rhinovirus_Enterovirus  Mycoplasma_pneumoniae  \
# 0             NaN                    NaN                    NaN
# 1    not_detected               detected                    NaN
# 2             NaN                    NaN                    NaN
# 3             NaN                    NaN                    NaN
# 4    not_detected               detected                    NaN
#
#   Coronavirus_HKU1 Parainfluenza_3 Chlamydophila_pneumoniae    Adenovirus  \
# 0              NaN             NaN                      NaN           NaN
# 1     not_detected    not_detected             not_detected  not_detected
# 2              NaN             NaN                      NaN           NaN
# 3              NaN             NaN                      NaN           NaN
# 4     not_detected    not_detected             not_detected  not_detected
#
#   Parainfluenza_4 Coronavirus229E CoronavirusOC43 Inf_A_H1N1_2009  \
# 0             NaN             NaN             NaN             NaN
# 1    not_detected    not_detected    not_detected    not_detected
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4    not_detected    not_detected    not_detected    not_detected
#
#   Bordetella_pertussis Metapneumovirus Parainfluenza_2  Neutrophils      Urea  \
# 0                  NaN             NaN             NaN          NaN       NaN
# 1         not_detected    not_detected    not_detected    -0.619086  1.198059
# 2                  NaN             NaN             NaN          NaN       NaN
# 3                  NaN             NaN             NaN          NaN       NaN
# 4         not_detected    not_detected    not_detected          NaN       NaN
#
#    Proteina_C_reativa_mg_dL  Creatinine  Potassium    Sodium  \
# 0                       NaN         NaN        NaN       NaN
# 1                 -0.147895    2.089928  -0.305787  0.862512
# 2                       NaN         NaN        NaN       NaN
# 3                       NaN         NaN        NaN       NaN
# 4                       NaN         NaN        NaN       NaN
#
#   Influenza_B__rapid_test Influenza_A__rapid_test  Alanine_transaminase  \
# 0                     NaN                     NaN                   NaN
# 1                negative                negative                   NaN
# 2                     NaN                     NaN                   NaN
# 3                     NaN                     NaN                   NaN
# 4                     NaN                     NaN                   NaN
#
#    Aspartate_transaminase  Gamma_glutamyltransferase_  Total_Bilirubin  \
# 0                     NaN                         NaN              NaN
# 1                     NaN                         NaN              NaN
# 2                     NaN                         NaN              NaN
# 3                     NaN                         NaN              NaN
# 4                     NaN                         NaN              NaN
#
#    Direct_Bilirubin  Indirect_Bilirubin  Alkaline_phosphatase  \
# 0               NaN                 NaN                   NaN
# 1               NaN                 NaN                   NaN
# 2               NaN                 NaN                   NaN
# 3               NaN                 NaN                   NaN
# 4               NaN                 NaN                   NaN
#
#    Ionized_calcium_  ... pCO2__venous_blood_gas_analysis_  \
# 0               NaN  ...                              NaN
# 1               NaN  ...                              NaN
# 2               NaN  ...                              NaN
# 3               NaN  ...                              NaN
# 4               NaN  ...                              NaN
#
#    Hb_saturation__venous_blood_gas_analysis_  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Base_excess__venous_blood_gas_analysis_  pO2__venous_blood_gas_analysis_  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#    Fio2__venous_blood_gas_analysis_  Total_CO2__venous_blood_gas_analysis_  \
# 0                               NaN                                    NaN
# 1                               NaN                                    NaN
# 2                               NaN                                    NaN
# 3                               NaN                                    NaN
# 4                               NaN                                    NaN
#
#    pH__venous_blood_gas_analysis_  HCO3__venous_blood_gas_analysis_  Rods__  \
# 0                             NaN                               NaN     NaN
# 1                             NaN                               NaN     NaN
# 2                             NaN                               NaN     NaN
# 3                             NaN                               NaN     NaN
# 4                             NaN                               NaN     NaN
#
#    Segmented  Promyelocytes  Metamyelocytes  Myelocytes  Myeloblasts  \
# 0        NaN            NaN             NaN         NaN          NaN
# 1        NaN            NaN             NaN         NaN          NaN
# 2        NaN            NaN             NaN         NaN          NaN
# 3        NaN            NaN             NaN         NaN          NaN
# 4        NaN            NaN             NaN         NaN          NaN
#
#    Urine___Esterase  Urine___Aspect Urine___pH Urine___Hemoglobin  \
# 0               NaN             NaN        NaN                NaN
# 1               NaN             NaN        NaN                NaN
# 2               NaN             NaN        NaN                NaN
# 3               NaN             NaN        NaN                NaN
# 4               NaN             NaN        NaN                NaN
#
#    Urine___Bile_pigments Urine___Ketone_Bodies Urine___Nitrite  \
# 0                    NaN                   NaN             NaN
# 1                    NaN                   NaN             NaN
# 2                    NaN                   NaN             NaN
# 3                    NaN                   NaN             NaN
# 4                    NaN                   NaN             NaN
#
#   Urine___Density Urine___Urobilinogen  Urine___Protein Urine___Sugar  \
# 0             NaN                  NaN              NaN           NaN
# 1             NaN                  NaN              NaN           NaN
# 2             NaN                  NaN              NaN           NaN
# 3             NaN                  NaN              NaN           NaN
# 4             NaN                  NaN              NaN           NaN
#
#   Urine___Leukocytes  Urine___Crystals  Urine___Red_blood_cells  \
# 0                NaN               NaN                      NaN
# 1                NaN               NaN                      NaN
# 2                NaN               NaN                      NaN
# 3                NaN               NaN                      NaN
# 4                NaN               NaN                      NaN
#
#   Urine___Hyaline_cylinders  Urine___Granular_cylinders Urine___Yeasts  \
# 0                       NaN                         NaN            NaN
# 1                       NaN                         NaN            NaN
# 2                       NaN                         NaN            NaN
# 3                       NaN                         NaN            NaN
# 4                       NaN                         NaN            NaN
#
#   Urine___Color Partial_thromboplastin_time__PTT__  \
# 0           NaN                                NaN
# 1           NaN                                NaN
# 2           NaN                                NaN
# 3           NaN                                NaN
# 4           NaN                                NaN
#
#   Relationship__Patient_Normal_  International_normalized_ratio__INR_  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
#    Lactic_Dehydrogenase  Prothrombin_time__PT___Activity  Vitamin_B12  \
# 0                   NaN                              NaN          NaN
# 1                   NaN                              NaN          NaN
# 2                   NaN                              NaN          NaN
# 3                   NaN                              NaN          NaN
# 4                   NaN                              NaN          NaN
#
#    Creatine_phosphokinase__CPK__  Ferritin  Arterial_Lactic_Acid  \
# 0                            NaN       NaN                   NaN
# 1                            NaN       NaN                   NaN
# 2                            NaN       NaN                   NaN
# 3                            NaN       NaN                   NaN
# 4                            NaN       NaN                   NaN
#
#    Lipase_dosage  D_Dimer  Albumin  Hb_saturation__arterial_blood_gases_  \
# 0            NaN      NaN      NaN                                   NaN
# 1            NaN      NaN      NaN                                   NaN
# 2            NaN      NaN      NaN                                   NaN
# 3            NaN      NaN      NaN                                   NaN
# 4            NaN      NaN      NaN                                   NaN
#
#    pCO2__arterial_blood_gas_analysis_  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Base_excess__arterial_blood_gas_analysis_  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    pH__arterial_blood_gas_analysis_  Total_CO2__arterial_blood_gas_analysis_  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    HCO3__arterial_blood_gas_analysis_  pO2__arterial_blood_gas_analysis_  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#    Arteiral_Fio2  Phosphor  ctO2__arterial_blood_gas_analysis_  admitted
# 0            NaN       NaN                                 NaN         0
# 1            NaN       NaN                                 NaN         0
# 2            NaN       NaN                                 NaN         0
# 3            NaN       NaN                                 NaN         0
# 4            NaN       NaN                                 NaN         0
#
# [5 rows x 112 columns]

# %%
X = data.iloc[:, 6:]
X['Patient_age_quantile'] = data['Patient_age_quantile']
X.head()
# Out:
#      Hematocrit  Hemoglobin  Platelets  Mean_platelet_volume_  \
# 67          NaN         NaN        NaN                    NaN
# 284         NaN         NaN        NaN                    NaN
# 513         NaN         NaN        NaN                    NaN
# 568    0.991838    0.792188  -0.341548               1.469188
# 676         NaN         NaN        NaN                    NaN
#
#      Red_blood_Cells  Lymphocytes  \
# 67               NaN          NaN
# 284              NaN          NaN
# 513              NaN          NaN
# 568         1.653476    -0.048383
# 676              NaN          NaN
#
#      Mean_corpuscular_hemoglobin_concentration__MCHC_  Leukocytes  Basophils  \
# 67                                                NaN         NaN        NaN
# 284                                               NaN         NaN        NaN
# 513                                               NaN         NaN        NaN
# 568                                         -0.452899   -0.420197   1.303529
# 676                                               NaN         NaN        NaN
#
#      Mean_corpuscular_hemoglobin__MCH_  Eosinophils  \
# 67                                 NaN          NaN
# 284                                NaN          NaN
# 513                                NaN          NaN
# 568                          -1.442245    -0.498393
# 676                                NaN          NaN
#
#      Mean_corpuscular_volume__MCV_  Monocytes  \
# 67                             NaN        NaN
# 284                            NaN        NaN
# 513                            NaN        NaN
# 568                      -1.396114   1.933339
# 676                            NaN        NaN
#
#      Red_blood_cell_distribution_width__RDW_  Serum_Glucose  \
# 67                                       NaN            NaN
# 284                                      NaN            NaN
# 513                                      NaN            NaN
# 568                                 0.967144            NaN
# 676                                      NaN            NaN
#
#     Respiratory_Syncytial_Virus   Influenza_A   Influenza_B Parainfluenza_1  \
# 67                          NaN           NaN           NaN             NaN
# 284                not_detected  not_detected  not_detected    not_detected
# 513                not_detected  not_detected  not_detected    not_detected
# 568                not_detected  not_detected  not_detected    not_detected
# 676                         NaN           NaN           NaN             NaN
#
#     CoronavirusNL63 Rhinovirus_Enterovirus  Mycoplasma_pneumoniae  \
# 67              NaN                    NaN                    NaN
# 284    not_detected           not_detected                    NaN
# 513    not_detected           not_detected                    NaN
# 568    not_detected           not_detected                    NaN
# 676             NaN                    NaN                    NaN
#
#     Coronavirus_HKU1 Parainfluenza_3 Chlamydophila_pneumoniae    Adenovirus  \
# 67               NaN             NaN                      NaN           NaN
# 284     not_detected    not_detected             not_detected  not_detected
# 513     not_detected    not_detected             not_detected  not_detected
# 568     not_detected    not_detected             not_detected  not_detected
# 676              NaN             NaN                      NaN           NaN
#
#     Parainfluenza_4 Coronavirus229E CoronavirusOC43 Inf_A_H1N1_2009  \
# 67              NaN             NaN             NaN             NaN
# 284    not_detected    not_detected    not_detected    not_detected
# 513    not_detected    not_detected    not_detected    not_detected
# 568    not_detected    not_detected    not_detected    not_detected
# 676             NaN             NaN             NaN             NaN
#
#     Bordetella_pertussis Metapneumovirus Parainfluenza_2  Neutrophils  \
# 67                   NaN             NaN             NaN          NaN
# 284         not_detected    not_detected    not_detected          NaN
# 513         not_detected    not_detected    not_detected          NaN
# 568         not_detected    not_detected    not_detected    -0.414215
# 676                  NaN             NaN             NaN          NaN
#
#          Urea  Proteina_C_reativa_mg_dL  Creatinine  Potassium    Sodium  \
# 67        NaN                       NaN         NaN        NaN       NaN
# 284       NaN                       NaN         NaN        NaN       NaN
# 513       NaN                       NaN         NaN        NaN       NaN
# 568 -0.513909                       NaN    -0.32234  -0.058626  0.143752
# 676       NaN                       NaN         NaN        NaN       NaN
#
#     Influenza_B__rapid_test Influenza_A__rapid_test  Alanine_transaminase  \
# 67                      NaN                     NaN                   NaN
# 284                     NaN                     NaN                   NaN
# 513                     NaN                     NaN                   NaN
# 568                     NaN                     NaN             -0.504127
# 676                     NaN                     NaN                   NaN
#
#      Aspartate_transaminase  Gamma_glutamyltransferase_  Total_Bilirubin  \
# 67                      NaN                         NaN              NaN
# 284                     NaN                         NaN              NaN
# 513                     NaN                         NaN              NaN
# 568               -0.317035                   -0.330608         1.355535
# 676                     NaN                         NaN              NaN
#
#      Direct_Bilirubin  Indirect_Bilirubin  Alkaline_phosphatase  \
# 67                NaN                 NaN                   NaN
# 284               NaN                 NaN                   NaN
# 513               NaN                 NaN                   NaN
# 568          1.163312            1.198484              3.060642
# 676               NaN                 NaN                   NaN
#
#      Ionized_calcium_ Strepto_A  Magnesium  pCO2__venous_blood_gas_analysis_  \
# 67                NaN       NaN        NaN                               NaN
# 284               NaN       NaN        NaN                               NaN
# 513               NaN       NaN        NaN                               NaN
# 568               NaN       NaN        NaN                         -0.090035
# 676               NaN       NaN        NaN                               NaN
#
#      Hb_saturation__venous_blood_gas_analysis_  \
# 67                                         NaN
# 284                                        NaN
# 513                                        NaN
# 568                                   0.337027
# 676                                        NaN
#
#      Base_excess__venous_blood_gas_analysis_  pO2__venous_blood_gas_analysis_  \
# 67                                       NaN                              NaN
# 284                                      NaN                              NaN
# 513                                      NaN                              NaN
# 568                                -0.611396                        -0.084646
# 676                                      NaN                              NaN
#
#      Fio2__venous_blood_gas_analysis_  Total_CO2__venous_blood_gas_analysis_  \
# 67                                NaN                                    NaN
# 284                               NaN                                    NaN
# 513                               NaN                                    NaN
# 568                               NaN                              -0.479346
# 676                               NaN                                    NaN
#
#      pH__venous_blood_gas_analysis_  HCO3__venous_blood_gas_analysis_  Rods__  \
# 67                              NaN                               NaN     NaN
# 284                             NaN                               NaN     NaN
# 513                             NaN                               NaN     NaN
# 568                       -0.436537                         -0.512865     NaN
# 676                             NaN                               NaN     NaN
#
#      Segmented  Promyelocytes  Metamyelocytes  Myelocytes  Myeloblasts  \
# 67         NaN            NaN             NaN         NaN          NaN
# 284        NaN            NaN             NaN         NaN          NaN
# 513        NaN            NaN             NaN         NaN          NaN
# 568        NaN            NaN             NaN         NaN          NaN
# 676        NaN            NaN             NaN         NaN          NaN
#
#     Urine___Esterase Urine___Aspect  Urine___pH Urine___Hemoglobin  \
# 67               NaN            NaN         NaN                NaN
# 284              NaN            NaN         NaN                NaN
# 513              NaN            NaN         NaN                NaN
# 568              NaN            NaN         NaN                NaN
# 676              NaN            NaN         NaN                NaN
#
#     Urine___Bile_pigments Urine___Ketone_Bodies Urine___Nitrite  \
# 67                    NaN                   NaN             NaN
# 284                   NaN                   NaN             NaN
# 513                   NaN                   NaN             NaN
# 568                   NaN                   NaN             NaN
# 676                   NaN                   NaN             NaN
#
#      Urine___Density Urine___Urobilinogen Urine___Protein  Urine___Sugar  \
# 67               NaN                  NaN             NaN            NaN
# 284              NaN                  NaN             NaN            NaN
# 513              NaN                  NaN             NaN            NaN
# 568              NaN                  NaN             NaN            NaN
# 676              NaN                  NaN             NaN            NaN
#
#      Urine___Leukocytes Urine___Crystals  Urine___Red_blood_cells  \
# 67                  NaN              NaN                      NaN
# 284                 NaN              NaN                      NaN
# 513                 NaN              NaN                      NaN
# 568                 NaN              NaN                      NaN
# 676                 NaN              NaN                      NaN
#
#     Urine___Hyaline_cylinders Urine___Granular_cylinders Urine___Yeasts  \
# 67                        NaN                        NaN            NaN
# 284                       NaN                        NaN            NaN
# 513                       NaN                        NaN            NaN
# 568                       NaN                        NaN            NaN
# 676                       NaN                        NaN            NaN
#
#     Urine___Color  Partial_thromboplastin_time__PTT__  \
# 67            NaN                                 NaN
# 284           NaN                                 NaN
# 513           NaN                                 NaN
# 568           NaN                                 NaN
# 676           NaN                                 NaN
#
#      Relationship__Patient_Normal_  International_normalized_ratio__INR_  \
# 67                             NaN                                   NaN
# 284                            NaN                                   NaN
# 513                            NaN                                   NaN
# 568                       0.000994                               0.86241
# 676                            NaN                                   NaN
#
#      Lactic_Dehydrogenase  Prothrombin_time__PT___Activity  Vitamin_B12  \
# 67                    NaN                              NaN          NaN
# 284                   NaN                              NaN          NaN
# 513                   NaN                              NaN          NaN
# 568             -0.620717                              NaN          NaN
# 676                   NaN                              NaN          NaN
#
#      Creatine_phosphokinase__CPK__  Ferritin  Arterial_Lactic_Acid  \
# 67                             NaN       NaN                   NaN
# 284                            NaN       NaN                   NaN
# 513                            NaN       NaN                   NaN
# 568                       0.125483       NaN                   NaN
# 676                            NaN       NaN                   NaN
#
#      Lipase_dosage  D_Dimer  Albumin  Hb_saturation__arterial_blood_gases_  \
# 67             NaN      NaN      NaN                                   NaN
# 284            NaN      NaN      NaN                                   NaN
# 513            NaN      NaN      NaN                                   NaN
# 568            NaN      NaN      NaN                                   NaN
# 676            NaN      NaN      NaN                                   NaN
#
#      pCO2__arterial_blood_gas_analysis_  \
# 67                                  NaN
# 284                                 NaN
# 513                                 NaN
# 568                                 NaN
# 676                                 NaN
#
#      Base_excess__arterial_blood_gas_analysis_  \
# 67                                         NaN
# 284                                        NaN
# 513                                        NaN
# 568                                        NaN
# 676                                        NaN
#
#      pH__arterial_blood_gas_analysis_  \
# 67                                NaN
# 284                               NaN
# 513                               NaN
# 568                               NaN
# 676                               NaN
#
#      Total_CO2__arterial_blood_gas_analysis_  \
# 67                                       NaN
# 284                                      NaN
# 513                                      NaN
# 568                                      NaN
# 676                                      NaN
#
#      HCO3__arterial_blood_gas_analysis_  pO2__arterial_blood_gas_analysis_  \
# 67                                  NaN                                NaN
# 284                                 NaN                                NaN
# 513                                 NaN                                NaN
# 568                                 NaN                                NaN
# 676                                 NaN                                NaN
#
#      Arteiral_Fio2  Phosphor  ctO2__arterial_blood_gas_analysis_  admitted  \
# 67             NaN       NaN                                 NaN         0
# 284            NaN       NaN                                 NaN         1
# 513            NaN       NaN                                 NaN         0
# 568            NaN       NaN                                 NaN         0
# 676            NaN       NaN                                 NaN         0
#
#      Patient_age_quantile
# 67                      7
# 284                    16
# 513                    10
# 568                     2
# 676                    15

# %%
kf = KFold(2, shuffle=True, random_state=0)

# %%
from sklearn.tree import plot_tree, DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn.metrics import mean_squared_error, cohen_kappa_score, classification_report, roc_auc_score

# %%
from category_encoders import OrdinalEncoder, TargetEncoder, OneHotEncoder

# %%
cats = X.select_dtypes(include=object).columns.tolist()

# %%
full_nan = X.isnull().mean(axis=1) == 1
covid = data['SARS_Cov_2_exam_result'] == 1
cond = ~full_nan & covid
X = X[cond]
data = data[cond]

# %%
X.shape
# Out:
# (558, 106)

# %%
data['admitted'].value_counts()
# Out:
# 0    506
# 1     52
# Name: admitted, dtype: int64

# %%
label = 'admitted'
for tr, ts in kf.split(X):
    Xtr = X.iloc[tr]
    ytr = X.iloc[tr][label]
    Xts = X.iloc[ts]
    yts = X.iloc[ts][label]
    
    enc = OneHotEncoder(cols=cats, use_cat_names=True)
    Xtr = enc.fit_transform(Xtr, ytr)
    Xts = enc.transform(Xts).drop(label, axis=1)
    
    ag_train = task.Dataset(df=Xtr)
    
    mdl = task.fit(train_data=ag_train, label=label, output_directory='models', auto_stack=False, 
               hyperparameter_tune=True, eval_metric='roc_auc', stopping_metric='roc_auc', num_bagging_folds=1,  
               feature_prune=True)

    p = mdl.predict_proba(Xts)
    
    print("AUC = ", roc_auc_score(yts,p))
    print(classification_report(yts, p > 0.5))
    print()
    
    break
# Out:
# Warning: feature_prune does not currently work, setting to False.
# Warning: `hyperparameter_tune=True` is currently experimental and may cause the process to hang. Setting `auto_stack=True` instead is recommended to achieve maximum quality models.
# Beginning AutoGluon training ...
# AutoGluon will save models to models/
# Train Data Rows:    279
# Train Data Columns: 145
# Preprocessing data ...
# Here are the first 10 unique label values in your data:  [0 1]
# AutoGluon infers your prediction problem is: binary  (because only two unique label-values observed)
# If this is wrong, please specify `problem_type` argument in fit() instead (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
#
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Feature Generator processed 279 data points with 134 features
# Original Features:
# 	float features: 63
# 	int features: 71
# Generated Features:
# 	int features: 0
# All Features:
# 	float features: 63
# 	int features: 71
# 	Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: roc_auc
# This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: roc_auc
# 	0.8784	 = Validation roc_auc score
# 	0.51s	 = Training runtime
# 	0.12s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	0.51s	 = Training runtime
# 	0.12s	 = Validation runtime
# 	0.8882	 = Validation roc_auc score
# 	0.4s	 = Training runtime
# 	0.12s	 = Validation runtime
# 	0.8882	 = Validation roc_auc score
# 	0.41s	 = Training runtime
# 	0.12s	 = Validation runtime
# 	0.7647	 = Validation roc_auc score
# 	0.04s	 = Training runtime
# 	0.14s	 = Validation runtime
# 	0.7686	 = Validation roc_auc score
# 	0.04s	 = Training runtime
# 	0.14s	 = Validation runtime
# Starting Experiments
# Num of Finished Tasks is 0
# Num of Pending Tasks is 1000
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# Finished Task with config: {'feature_fraction': 1.0, 'learning_rate': 0.1, 'min_data_in_leaf': 20, 'num_leaves': 31} and reward: 0.984313725490196
# Finished Task with config: {'feature_fraction': 0.7873140510798202, 'learning_rate': 0.011046255312371127, 'min_data_in_leaf': 19, 'num_leaves': 56} and reward: 0.9568627450980393
# Finished Task with config: {'feature_fraction': 0.882863665643949, 'learning_rate': 0.014807628795080281, 'min_data_in_leaf': 5, 'num_leaves': 55} and reward: 0.9921568627450981
# Finished Task with config: {'feature_fraction': 0.9005313155276706, 'learning_rate': 0.00512950099193351, 'min_data_in_leaf': 26, 'num_leaves': 23} and reward: 0.9568627450980391
# Finished Task with config: {'feature_fraction': 0.9310607150253289, 'learning_rate': 0.06839359061357882, 'min_data_in_leaf': 20, 'num_leaves': 18} and reward: 0.9921568627450981
# Finished Task with config: {'feature_fraction': 0.7866621799228856, 'learning_rate': 0.05157174522714467, 'min_data_in_leaf': 22, 'num_leaves': 76} and reward: 0.9647058823529412
# Finished Task with config: {'feature_fraction': 0.933074438217192, 'learning_rate': 0.005342381845200192, 'min_data_in_leaf': 3, 'num_leaves': 45} and reward: 0.9411764705882353
# Finished Task with config: {'feature_fraction': 0.9430665434971482, 'learning_rate': 0.17877000957182718, 'min_data_in_leaf': 25, 'num_leaves': 74} and reward: 0.9411764705882354
# Finished Task with config: {'feature_fraction': 0.8330288379233225, 'learning_rate': 0.024128351175865384, 'min_data_in_leaf': 19, 'num_leaves': 54} and reward: 0.9647058823529412
# Finished Task with config: {'feature_fraction': 0.9793870893331202, 'learning_rate': 0.04990943258901069, 'min_data_in_leaf': 16, 'num_leaves': 44} and reward: 0.9843137254901961
# Finished Task with config: {'feature_fraction': 0.9822652600357749, 'learning_rate': 0.053854422187140205, 'min_data_in_leaf': 27, 'num_leaves': 34} and reward: 0.9725490196078431
# Finished Task with config: {'feature_fraction': 0.9846404720758275, 'learning_rate': 0.009582505487826212, 'min_data_in_leaf': 12, 'num_leaves': 59} and reward: 0.9607843137254902
# Finished Task with config: {'feature_fraction': 0.7594811346005171, 'learning_rate': 0.1514720933265693, 'min_data_in_leaf': 5, 'num_leaves': 60} and reward: 0.9882352941176471
# Finished Task with config: {'feature_fraction': 0.8212940253973551, 'learning_rate': 0.00670723024030823, 'min_data_in_leaf': 22, 'num_leaves': 67} and reward: 0.9549019607843138
# Finished Task with config: {'feature_fraction': 0.921573188759907, 'learning_rate': 0.0069984853613723405, 'min_data_in_leaf': 19, 'num_leaves': 59} and reward: 0.9568627450980393
# Finished Task with config: {'feature_fraction': 0.9758287425209122, 'learning_rate': 0.011155016610636462, 'min_data_in_leaf': 20, 'num_leaves': 40} and reward: 0.9686274509803922
# Finished Task with config: {'feature_fraction': 0.9732939088487043, 'learning_rate': 0.184899729255251, 'min_data_in_leaf': 4, 'num_leaves': 16} and reward: 0.984313725490196
# Finished Task with config: {'feature_fraction': 0.8926737466381074, 'learning_rate': 0.00850015851816802, 'min_data_in_leaf': 24, 'num_leaves': 61} and reward: 0.9607843137254902
# Finished Task with config: {'feature_fraction': 0.9422548769851088, 'learning_rate': 0.0285542756859032, 'min_data_in_leaf': 19, 'num_leaves': 66} and reward: 0.9647058823529411
# Finished Task with config: {'feature_fraction': 0.9665088927750161, 'learning_rate': 0.017307514168718816, 'min_data_in_leaf': 2, 'num_leaves': 84} and reward: 0.9098039215686274
# Finished Task with config: {'feature_fraction': 0.8288913199415852, 'learning_rate': 0.09942221383893335, 'min_data_in_leaf': 7, 'num_leaves': 18} and reward: 0.9764705882352942
# Finished Task with config: {'feature_fraction': 0.9544243252722, 'learning_rate': 0.014094863230934248, 'min_data_in_leaf': 19, 'num_leaves': 65} and reward: 0.9529411764705882
# Finished Task with config: {'feature_fraction': 0.7933166415775699, 'learning_rate': 0.13365401902184637, 'min_data_in_leaf': 16, 'num_leaves': 65} and reward: 0.9882352941176471
# Finished Task with config: {'feature_fraction': 0.9827355076103657, 'learning_rate': 0.014494342050201132, 'min_data_in_leaf': 7, 'num_leaves': 26} and reward: 0.9803921568627451
# Finished Task with config: {'feature_fraction': 0.8124425481903188, 'learning_rate': 0.026695209771183847, 'min_data_in_leaf': 2, 'num_leaves': 93} and reward: 0.9137254901960783
# Finished Task with config: {'feature_fraction': 0.9882628688178197, 'learning_rate': 0.022785462008299454, 'min_data_in_leaf': 27, 'num_leaves': 64} and reward: 0.9725490196078432
# Finished Task with config: {'feature_fraction': 0.9327815159113361, 'learning_rate': 0.06855340566006757, 'min_data_in_leaf': 4, 'num_leaves': 82} and reward: 0.9764705882352942
# 	Ran out of time, early stopping on iteration 231. Best iteration is:
# 	[86]	train_set's binary_logloss: 0.0725962	train_set's binary_error: 0.0224215	train_set's roc_auc: 0.989901	valid_set's binary_logloss: 0.250823	valid_set's binary_error: 0.125	valid_set's roc_auc: 0.931373
# Finished Task with config: {'feature_fraction': 0.8847443846418009, 'learning_rate': 0.09510241035863279, 'min_data_in_leaf': 30, 'num_leaves': 32} and reward: 0.9
# 	0.9961	 = Validation roc_auc score
# 	3.73s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	2.11s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9922	 = Validation roc_auc score
# 	4.53s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9706	 = Validation roc_auc score
# 	1.88s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9922	 = Validation roc_auc score
# 	3.98s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.84s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9608	 = Validation roc_auc score
# 	4.02s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.37s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.72s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9843	 = Validation roc_auc score
# 	3.36s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.85s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9608	 = Validation roc_auc score
# 	2.61s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	1.0	 = Validation roc_auc score
# 	1.75s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9588	 = Validation roc_auc score
# 	1.34s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	2.75s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	2.72s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9843	 = Validation roc_auc score
# 	1.61s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	2.4s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.82s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9608	 = Validation roc_auc score
# 	3.05s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9843	 = Validation roc_auc score
# 	2.34s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	2.15s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9922	 = Validation roc_auc score
# 	2.54s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	6.11s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	2.98s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	2.66s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9843	 = Validation roc_auc score
# 	3.03s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9314	 = Validation roc_auc score
# 	1.63s	 = Training runtime
# 	0.02s	 = Validation runtime
# Starting Experiments
# Num of Finished Tasks is 0
# Num of Pending Tasks is 1000
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 3.0, 'learning_rate': 0.1} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.583115975715544, 'learning_rate': 0.011994327556995034} and reward: 0.9647058823529412
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.7005059434514447, 'learning_rate': 0.022881590915946385} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 3.3857718034861226, 'learning_rate': 0.04122187153403603} and reward: 0.9725490196078432
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 1.7203077526341297, 'learning_rate': 0.057427768075634565} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 3.9709638794256055, 'learning_rate': 0.012187918759174996} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 3.853170716651735, 'learning_rate': 0.1574712520493656} and reward: 0.9764705882352941
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.63092729046285, 'learning_rate': 0.11691082970095425} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 4.892153035589736, 'learning_rate': 0.17839679831370858} and reward: 0.9803921568627452
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.7317001280045403, 'learning_rate': 0.05637006536173556} and reward: 0.9725490196078432
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 2.771544529726392, 'learning_rate': 0.023746884171593336} and reward: 0.9803921568627452
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 1.402011900295685, 'learning_rate': 0.01379263586763835} and reward: 0.9745098039215686
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 3.0542068849925794, 'learning_rate': 0.046921461087457615} and reward: 0.9764705882352941
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 3.0949243596714893, 'learning_rate': 0.05517197444103367} and reward: 0.9725490196078431
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 4.9124437838668955, 'learning_rate': 0.18376741157453683} and reward: 0.9745098039215687
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 2.4805603126547693, 'learning_rate': 0.10233343350329625} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 3.081521712490291, 'learning_rate': 0.09848174906189665} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 1.3511912306581526, 'learning_rate': 0.0491309298744206} and reward: 0.9803921568627452
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 2.2400136402627138, 'learning_rate': 0.02033027914611946} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 3.8304803618106162, 'learning_rate': 0.007846161112316246} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 1.725557340883578, 'learning_rate': 0.014741079475693161} and reward: 0.9764705882352941
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 4.327321938724935, 'learning_rate': 0.02479080227635335} and reward: 0.9745098039215686
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 4.876739334051427, 'learning_rate': 0.02830197465236186} and reward: 0.9745098039215687
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 4.825551660086708, 'learning_rate': 0.19469799037405128} and reward: 0.9803921568627452
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.7597425028825726, 'learning_rate': 0.01836418461149249} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 2.3592228137883113, 'learning_rate': 0.005132819229035533} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 4.638821048153876, 'learning_rate': 0.006745227981879559} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 2.2354715673409187, 'learning_rate': 0.030850769142827087} and reward: 0.9803921568627451
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 4.263225039674422, 'learning_rate': 0.03085223267271992} and reward: 0.9647058823529412
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 4.1221243051100664, 'learning_rate': 0.020488885581896987} and reward: 0.9666666666666667
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 3.6177631117530127, 'learning_rate': 0.08036152834214093} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.670063508419812, 'learning_rate': 0.059880440913220055} and reward: 0.9686274509803923
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.53305399746645, 'learning_rate': 0.006842922933541033} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.584869423109745, 'learning_rate': 0.04486956929251376} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 4.346241757685981, 'learning_rate': 0.0133045245909141} and reward: 0.9647058823529412
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 4.789478810002468, 'learning_rate': 0.00825450383665883} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 1.3281511689050012, 'learning_rate': 0.0373476784394388} and reward: 0.9803921568627452
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.789141965659051, 'learning_rate': 0.06742576119278311} and reward: 0.9803921568627451
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 2.5501201708667747, 'learning_rate': 0.009703388843243378} and reward: 0.9725490196078432
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 4.647235472069636, 'learning_rate': 0.06710630525108237} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 4.522258388421263, 'learning_rate': 0.05492534860035752} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.58709322453261, 'learning_rate': 0.013673258782240435} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 3.039532576069725, 'learning_rate': 0.005672446657441799} and reward: 0.9647058823529412
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 4.146166465007836, 'learning_rate': 0.011005268625196803} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 5, 'l2_leaf_reg': 1.8748721030040945, 'learning_rate': 0.023739294131555004} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 3.335474152127215, 'learning_rate': 0.021637237793785194} and reward: 0.9666666666666667
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 3.136374377787406, 'learning_rate': 0.11158744220899869} and reward: 0.9764705882352942
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 4.4085940260067416, 'learning_rate': 0.07791017787772421} and reward: 0.9686274509803922
# Finished Task with config: {'depth': 7, 'l2_leaf_reg': 1.112585101048364, 'learning_rate': 0.01799667946137361} and reward: 0.9745098039215686
# Finished Task with config: {'depth': 6, 'l2_leaf_reg': 2.5666196194583946, 'learning_rate': 0.00845676764539698} and reward: 0.9647058823529413
# Finished Task with config: {'depth': 8, 'l2_leaf_reg': 3.6756537596466274, 'learning_rate': 0.12308949841958931} and reward: 0.9725490196078431
# 	0.9765	 = Validation roc_auc score
# 	1.5s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	0.99s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.98s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	2.14s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	2.12s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	0.96s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.82s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.66s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.38s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.61s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.23s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9745	 = Validation roc_auc score
# 	1.11s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.94s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.47s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9745	 = Validation roc_auc score
# 	1.57s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	2.24s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.61s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.43s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	0.94s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	0.91s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.07s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9745	 = Validation roc_auc score
# 	1.12s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9745	 = Validation roc_auc score
# 	1.31s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.46s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.08s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.48s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.7s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.62s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.02s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9667	 = Validation roc_auc score
# 	1.1s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.52s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.91s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.46s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.5s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.51s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.94s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.09s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9804	 = Validation roc_auc score
# 	1.55s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.81s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	0.99s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.36s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.42s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.01s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	0.9s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	0.96s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9667	 = Validation roc_auc score
# 	1.11s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9765	 = Validation roc_auc score
# 	1.16s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9686	 = Validation roc_auc score
# 	1.67s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9745	 = Validation roc_auc score
# 	1.09s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9647	 = Validation roc_auc score
# 	1.4s	 = Training runtime
# 	0.02s	 = Validation runtime
# 	0.9725	 = Validation roc_auc score
# 	1.01s	 = Training runtime
# 	0.02s	 = Validation runtime
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/trainer/abstract_trainer.py", line 361, in train_single_full
#     hpo_models, hpo_model_performances, hpo_results = model.hyperparameter_tune(X_train=X_train, X_test=X_test, Y_train=y_train, Y_test=y_test, scheduler_options=(self.scheduler_func, self.scheduler_options), verbosity=self.verbosity)
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 765, in hyperparameter_tune
#     train_dataset, test_dataset = self.generate_datasets(X_train=X_train, y_train=Y_train, params=params_copy, X_test=X_test, y_test=Y_test)
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 452, in generate_datasets
#     impute_strategy=impute_strategy, max_category_levels=max_category_levels, skew_threshold=skew_threshold, embed_min_categories=embed_min_categories,
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 520, in process_train_data
#     raise ValueError("Error during one-hot encoding data processing for neural network. Number of columns in df array does not match feature_arraycol_map.")
# Warning: Exception caused NeuralNetClassifier to fail during hyperparameter tuning... Skipping this model.
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/trainer/abstract_trainer.py", line 361, in train_single_full
#     hpo_models, hpo_model_performances, hpo_results = model.hyperparameter_tune(X_train=X_train, X_test=X_test, Y_train=y_train, Y_test=y_test, scheduler_options=(self.scheduler_func, self.scheduler_options), verbosity=self.verbosity)
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 765, in hyperparameter_tune
#     train_dataset, test_dataset = self.generate_datasets(X_train=X_train, y_train=Y_train, params=params_copy, X_test=X_test, y_test=Y_test)
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 452, in generate_datasets
#     impute_strategy=impute_strategy, max_category_levels=max_category_levels, skew_threshold=skew_threshold, embed_min_categories=embed_min_categories,
#   File "/home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/autogluon/utils/tabular/ml/models/tabular_nn/tabular_nn_model.py", line 520, in process_train_data
#     raise ValueError("Error during one-hot encoding data processing for neural network. Number of columns in df array does not match feature_arraycol_map.")
# ValueError: Error during one-hot encoding data processing for neural network. Number of columns in df array does not match feature_arraycol_map.
# Fitting model: weighted_ensemble_k0_l1 ...
# 	1.0	 = Validation roc_auc score
# 	1.67s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 162.75s ...
# AUC =  0.898883009994121
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       252
#            1       0.79      0.56      0.65        27
#
#     accuracy                           0.94       279
#    macro avg       0.87      0.77      0.81       279
# weighted avg       0.94      0.94      0.94       279
