# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet("./data/clean_data_merged_v1.parquet")
data['HomeTeamName'] = data['HomeTeamName'].str.strip()
data['AwayTeamName'] = data['AwayTeamName'].str.strip()

#data = data[data['date'].dt.year >= 1980].copy()
data['year'] = data['date'].dt.year

# %%
data.head(5)
# Out:
#                  date    HomeTeamName  AwayTeamName  HomeTeamGoals  \
# 0 1960-07-06 20:00:00          France    Yugoslavia              4
# 1 1960-07-06 21:30:00  Czechoslovakia  Soviet Union              0
# 2 1960-07-09 21:30:00  Czechoslovakia        France              2
# 3 1960-07-10 21:30:00    Soviet Union    Yugoslavia              2
# 4 1964-06-17 20:00:00           Spain       Hungary              2
#
#    AwayTeamGoals  y_classif  y_reg  year
# 0              5       -1.0     -1  1960
# 1              3       -1.0     -3  1960
# 2              0        1.0      2  1960
# 3              1        1.0      1  1960
# 4              1        1.0      1  1964

# %%
participationh = data.groupby(["HomeTeamName", "year"]).size()#.reset_index()
participationa = data.groupby(["AwayTeamName", "year"]).size()#.reset_index()

participationh.index.names = ['team', 'year']
participationa.index.names = ['team', 'year']

participation = pd.DataFrame({"home": participationh, "away": participationa}).fillna(0).sum(axis=1).reset_index()
participation.columns = ['team', 'year', 'n_games']

participation = participation.sort_values("year")
participation['cumulative_games'] = participation.groupby("team")['n_games'].cumsum()

participation['year'] = participation['year'] + 1

# stats um time contra o outro

# %%
def fn_features(df, team_features):
    df_ = pd.merge_asof(df, team_features, left_by=['HomeTeamName'], right_by=['team'], on=['year'])
    df_ = pd.merge_asof(df_, team_features, left_by=['AwayTeamName'], right_by=['team'], on=['year'], suffixes=['_home', '_away'])
    
    return df_

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, log_loss, roc_auc_score
from sklearn.ensemble import RandomForestClassifier

# %%
34+21
# Out:
# 55

# %%
for year in [2004, 2008, 2012, 2016]:
    tr = data[data['year'] < year].copy()
    val = data[data['year'] == year].copy()
    
   
    selected_features = ['n_games_home', 'n_games_away', 'cumulative_games_home', 'cumulative_games_away']
    
    tr_ = fn_features(tr, participation)
    val_ = fn_features(val, participation)
    
    
    Xtr = tr_[selected_features].fillna(0)
    Xval = val_[selected_features].fillna(0)
    ytr = tr['y_classif']
    yval = val['y_classif']
    
    mdl = RandomForestClassifier(random_state=0, min_samples_leaf=34, n_estimators=300, n_jobs=6)
    mdl.fit(Xtr, ytr)
    
    p = mdl.predict_proba(Xval)
    
    
        
    baseline = ytr.value_counts(normalize=True)
    baseline.index = [2,0,1]
    baseline = np.ones((Xval.shape[0], 3)) * baseline.sort_index().values
    
    
    print("Ano: {} | Baseline Log Loss: {:.4f} | Baseline AUC: {:.4f} | Log Loss: {:.4f} | ROC AUC: {:.4f}\n".format(year, log_loss(yval, baseline),
            roc_auc_score(yval, baseline, multi_class='ovr'), log_loss(yval, p), roc_auc_score(yval,p, multi_class='ovr')))
# Out:
# Ano: 2004 | Baseline Log Loss: 1.1082 | Baseline AUC: 0.5000 | Log Loss: 1.1037 | ROC AUC: 0.5401
#
# Ano: 2008 | Baseline Log Loss: 1.0736 | Baseline AUC: 0.5000 | Log Loss: 1.0564 | ROC AUC: 0.5659
#
# Ano: 2012 | Baseline Log Loss: 1.0708 | Baseline AUC: 0.5000 | Log Loss: 1.0560 | ROC AUC: 0.5035
#
# Ano: 2016 | Baseline Log Loss: 1.0898 | Baseline AUC: 0.5000 | Log Loss: 1.0820 | ROC AUC: 0.5205

# %% [markdown]
# 2004 Baseline Home Win 0.3548387096774194
#               precision    recall  f1-score   support
#
#         -1.0       0.19      0.30      0.23        10
#          0.0       0.00      0.00      0.00        10
#          1.0       0.33      0.45      0.38        11
#
#     accuracy                           0.26        31
#    macro avg       0.17      0.25      0.21        31
# weighted avg       0.18      0.26      0.21        31
#
# 2004               precision    recall  f1-score   support
#
#         -1.0       0.27      0.40      0.32        10
#          0.0       0.00      0.00      0.00        10
#          1.0       0.44      0.64      0.52        11
#
#     accuracy                           0.35        31
#    macro avg       0.23      0.35      0.28        31
# weighted avg       0.24      0.35      0.29        31
#
#
#
# 2008 Baseline Historical wins 0.41935483870967744
# 2008 Baseline Home Win 0.3548387096774194
#               precision    recall  f1-score   support
#
#         -1.0       0.47      0.53      0.50        15
#          0.0       0.00      0.00      0.00         5
#          1.0       0.36      0.45      0.40        11
#
#     accuracy                           0.42        31
#    macro avg       0.28      0.33      0.30        31
# weighted avg       0.35      0.42      0.38        31
#
#
# 2008               precision    recall  f1-score   support
#
#         -1.0       0.62      0.53      0.57        15
#          0.0       0.17      0.20      0.18         5
#          1.0       0.42      0.45      0.43        11
#
#     accuracy                           0.45        31
#    macro avg       0.40      0.40      0.40        31
# weighted avg       0.47      0.45      0.46        31
#
#
# 2012 Baseline Historical wins 0.2903225806451613
# 2012 Baseline Home Win 0.41935483870967744
#               precision    recall  f1-score   support
#
#         -1.0       0.30      0.55      0.39        11
#          0.0       0.00      0.00      0.00         7
#          1.0       0.27      0.23      0.25        13
#
#     accuracy                           0.29        31
#    macro avg       0.19      0.26      0.21        31
# weighted avg       0.22      0.29      0.24        31
#
# 2012               precision    recall  f1-score   support
#
#         -1.0       0.41      0.82      0.55        11
#          0.0       0.00      0.00      0.00         7
#          1.0       0.67      0.46      0.55        13
#
#     accuracy                           0.48        31
#    macro avg       0.36      0.43      0.36        31
# weighted avg       0.42      0.48      0.42        31
#
#
# 2016 Baseline Historical wins 0.4117647058823529
# 2016 Baseline Home Win 0.39215686274509803
#               precision    recall  f1-score   support
#
#         -1.0       0.36      0.76      0.49        17
#          0.0       0.00      0.00      0.00        14
#          1.0       0.53      0.40      0.46        20
#
#     accuracy                           0.41        51
#    macro avg       0.30      0.39      0.32        51
# weighted avg       0.33      0.41      0.34        51
#
#
# 2016               precision    recall  f1-score   support
#
#         -1.0       0.42      0.47      0.44        17
#          0.0       0.00      0.00      0.00        14
#          1.0       0.47      0.75      0.58        20
#
#     accuracy                           0.45        51
#    macro avg       0.30      0.41      0.34        51
# weighted avg       0.32      0.45      0.37        51

# %%
val_
# Out:
#                   date    HomeTeamName    AwayTeamName  HomeTeamGoals  \
# 0  2004-06-12 17:00:00        Portugal          Greece              1
# 1  2004-06-12 19:45:00           Spain          Russia              1
# 2  2004-06-16 17:00:00          Greece           Spain              1
# 3  2004-06-16 19:45:00          Russia        Portugal              0
# 4  2004-06-20 19:45:00           Spain        Portugal              0
# 5  2004-06-20 19:45:00          Russia          Greece              2
# 6  2004-06-13 17:00:00     Switzerland         Croatia              0
# 7  2004-06-13 19:45:00          France         England              2
# 8  2004-06-17 17:00:00         England     Switzerland              3
# 9  2004-06-17 19:45:00         Croatia          France              2
# 10 2004-06-21 19:45:00         Croatia         England              2
# 11 2004-06-21 19:45:00     Switzerland          France              1
# 12 2004-06-14 17:00:00         Denmark           Italy              0
# 13 2004-06-14 19:45:00          Sweden        Bulgaria              5
# 14 2004-06-18 17:00:00        Bulgaria         Denmark              0
# 15 2004-06-18 19:45:00           Italy          Sweden              1
# 16 2004-06-22 19:45:00           Italy        Bulgaria              2
# 17 2004-06-22 19:45:00         Denmark          Sweden              2
# 18 2004-06-15 17:00:00  Czech Republic          Latvia              2
# 19 2004-06-15 19:45:00         Germany     Netherlands              1
# 20 2004-06-19 17:00:00          Latvia         Germany              0
# 21 2004-06-19 19:45:00     Netherlands  Czech Republic              2
# 22 2004-06-23 19:45:00     Netherlands          Latvia              3
# 23 2004-06-23 19:45:00         Germany  Czech Republic              1
# 24 2004-06-24 19:45:00        Portugal         England              2
# 25 2004-06-25 19:45:00          France          Greece              0
# 26 2004-06-26 19:45:00          Sweden     Netherlands              0
# 27 2004-06-27 19:45:00  Czech Republic         Denmark              3
# 28 2004-06-30 19:45:00        Portugal     Netherlands              2
# 29 2004-07-01 19:45:00          Greece  Czech Republic              1
# 30 2004-07-04 19:45:00        Portugal          Greece              0
#
#     AwayTeamGoals  y_classif  y_reg  year       team_home  n_games_home  \
# 0               2       -1.0     -1  2004        Portugal           5.0
# 1               0        1.0      1  2004           Spain           4.0
# 2               1        0.0      0  2004          Greece           3.0
# 3               2       -1.0     -2  2004          Russia           3.0
# 4               1       -1.0     -1  2004           Spain           4.0
# 5               1        1.0      1  2004          Russia           3.0
# 6               0        0.0      0  2004     Switzerland           3.0
# 7               1        1.0      1  2004          France           6.0
# 8               0        1.0      3  2004         England           3.0
# 9               2        0.0      0  2004         Croatia           4.0
# 10              4       -1.0     -2  2004         Croatia           4.0
# 11              3       -1.0     -2  2004     Switzerland           3.0
# 12              0        0.0      0  2004         Denmark           3.0
# 13              0        1.0      5  2004          Sweden           3.0
# 14              2       -1.0     -2  2004        Bulgaria           3.0
# 15              1        0.0      0  2004           Italy           6.0
# 16              1        1.0      1  2004           Italy           6.0
# 17              2        0.0      0  2004         Denmark           3.0
# 18              1        1.0      1  2004  Czech Republic           3.0
# 19              1        0.0      0  2004         Germany           3.0
# 20              0        0.0      0  2004             NaN           NaN
# 21              3       -1.0     -1  2004     Netherlands           5.0
# 22              0        1.0      3  2004     Netherlands           5.0
# 23              2       -1.0     -1  2004         Germany           3.0
# 24              2        0.0      0  2004        Portugal           5.0
# 25              1       -1.0     -1  2004          France           6.0
# 26              0        0.0      0  2004          Sweden           3.0
# 27              0        1.0      3  2004  Czech Republic           3.0
# 28              1        1.0      1  2004        Portugal           5.0
# 29              0        1.0      1  2004          Greece           3.0
# 30              1       -1.0     -1  2004        Portugal           5.0
#
#     cumulative_games_home       team_away  n_games_away  cumulative_games_away
# 0                    13.0          Greece           3.0                    3.0
# 1                    21.0          Russia           3.0                    3.0
# 2                     3.0           Spain           4.0                   21.0
# 3                     3.0        Portugal           5.0                   13.0
# 4                    21.0        Portugal           5.0                   13.0
# 5                     3.0          Greece           3.0                    3.0
# 6                     3.0         Croatia           4.0                    4.0
# 7                    21.0         England           3.0                   19.0
# 8                    19.0     Switzerland           3.0                    3.0
# 9                     4.0          France           6.0                   21.0
# 10                    4.0         England           3.0                   19.0
# 11                    3.0          France           6.0                   21.0
# 12                   20.0           Italy           6.0                   20.0
# 13                    7.0        Bulgaria           3.0                    3.0
# 14                    3.0         Denmark           3.0                   20.0
# 15                   20.0          Sweden           3.0                    7.0
# 16                   20.0        Bulgaria           3.0                    3.0
# 17                   20.0          Sweden           3.0                    7.0
# 18                    9.0             NaN           NaN                    NaN
# 19                   14.0     Netherlands           5.0                   23.0
# 20                    NaN         Germany           3.0                   14.0
# 21                   23.0  Czech Republic           3.0                    9.0
# 22                   23.0             NaN           NaN                    NaN
# 23                   14.0  Czech Republic           3.0                    9.0
# 24                   13.0         England           3.0                   19.0
# 25                   21.0          Greece           3.0                    3.0
# 26                    7.0     Netherlands           5.0                   23.0
# 27                    9.0         Denmark           3.0                   20.0
# 28                   13.0     Netherlands           5.0                   23.0
# 29                    3.0  Czech Republic           3.0                    9.0
# 30                   13.0          Greece           3.0                    3.0
