# %%
import pandas as pd

# %%
date = "2022-01-05"
data = pd.read_sql(f'SELECT * FROM yellow_tripdata WHERE tpep_pickup_datetime < "{date}"', 'sqlite:///data.db')
preds = pd.read_sql(f'SELECT * FROM predictions', 'sqlite:///data.db')

# %%
data.tail()
# Out:
#           index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 268862  2398555         2  2022-01-04 23:47:27   2022-01-04 23:55:03
# 268863  2398556         2  2022-01-04 23:44:58   2022-01-04 23:56:10
# 268864  2398557         2  2022-01-04 23:07:07   2022-01-04 23:10:54
# 268865  2398558         2  2022-01-04 23:43:00   2022-01-04 23:56:00
# 268866  2398559         2  2022-01-04 23:34:00   2022-01-04 23:45:00
#
#         passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 268862              NaN           1.66         NaN               None
# 268863              NaN           3.23         NaN               None
# 268864              NaN           0.55         NaN               None
# 268865              NaN           3.05         NaN               None
# 268866              NaN           3.66         NaN               None
#
#         PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
preds.tail()
# Out:
#           index  prediction
# 146962  2398555    2.694889
# 146963  2398556    3.326200
# 146964  2398557    4.061624
# 146965  2398558    3.535200
# 146966  2398559    2.957333

# %%
r = preds.merge(data[["index", "tip_amount"]], on="index", how="left")

# %%
r.head()
# Out:
#     index  prediction  tip_amount
# 0   97175    1.988800        4.21
# 1  101532    4.135173        7.41
# 2  114802    3.578470        5.55
# 3  117062    4.904552        8.62
# 4  117145    0.834859        0.00

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(r["tip_amount"], r["prediction"], squared=False)
# Out:
# 2.728058382025522
