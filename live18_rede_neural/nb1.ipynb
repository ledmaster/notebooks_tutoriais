# %%
import pandas as pd
import numpy as np
# %matplotlib inline
pd.set_option("display.max_columns", 81)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Começaremos às 20:05

# %% [markdown]
# # Fique em casa

# %% [markdown]
# # Quer aprender como fazer um projeto de machine learning da ideia até o deploy? CursoDeDataScience.com

# %% [markdown]
# # diferença sklearn vs tensorflow vs pytorch

# %%
import tensorflow as tf

# %%
data = pd.read_csv("data/train.csv")
X = data.drop(["Id","SalePrice"], axis=1)
y = data['SalePrice']

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
from sklearn.model_selection import train_test_split
Xtr, Xval, ytr, yval = train_test_split(X,y, train_size=0.5, random_state=0)

Xtr.shape, Xval.shape, ytr.shape, yval.shape
# Out:
# ((730, 79), (730, 79), (730,), (730,))

# %%
Xtr.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 733           20       RL         80.0    10000   Pave   NaN      Reg
# 382           60       RL         79.0     9245   Pave   NaN      IR1
# 1232          90       RL         70.0     9842   Pave   NaN      Reg
# 1354          60       RL          NaN    10316   Pave   NaN      IR1
# 331           20       RL         70.0     8176   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 733          Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
# 382          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1232         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1354         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 331          Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 733        Norm     1Fam     1Story            5            6       1961
# 382        Norm     1Fam     2Story            7            5       2006
# 1232       Norm   Duplex     1Story            4            5       1962
# 1354       Norm     1Fam     2Story            7            5       2000
# 331        Norm     1Fam     1Story            5            6       1958
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 733           1983       Hip  CompShg     HdBoard     HdBoard       None
# 382           2006     Gable  CompShg     VinylSd     VinylSd       None
# 1232          1962     Gable  CompShg     HdBoard     HdBoard       None
# 1354          2000     Gable  CompShg     VinylSd     VinylSd       None
# 331           1992     Gable  CompShg     Wd Sdng     Wd Sdng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 733          0.0        TA        TA     CBlock       TA       TA
# 382          0.0        Gd        TA      PConc       Gd       TA
# 1232         0.0        TA        TA       Slab      NaN      NaN
# 1354         0.0        Gd        TA      PConc       Gd       TA
# 331          0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 733            No          BLQ         594          Unf           0
# 382            Av          Unf           0          Unf           0
# 1232          NaN          NaN           0          NaN           0
# 1354           No          GLQ         735          Unf           0
# 331            No          Rec         846          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 733         270          864    GasA        Ex          Y      SBrkr
# 382         939          939    GasA        Ex          Y      SBrkr
# 1232          0            0    GasA        TA          Y      SBrkr
# 1354        257          992    GasA        Ex          Y      SBrkr
# 331         210         1056    GasA        Fa          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 733       1144         0             0       1144             1             0
# 382        939       858             0       1797             0             0
# 1232      1224         0             0       1224             0             0
# 1354       992       873             0       1865             1             0
# 331       1056         0             0       1056             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 733          1         0             3             1          TA
# 382          2         1             3             1          Gd
# 1232         2         0             2             2          TA
# 1354         2         1             3             1          Gd
# 331          1         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 733              6        Typ           1          TA     Attchd       1961.0
# 382              8        Typ           0         NaN     Attchd       2006.0
# 1232             6        Typ           0         NaN    CarPort       1962.0
# 1354             7        Typ           1          TA     Attchd       2000.0
# 331              6        Typ           0         NaN     Attchd       1958.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 733           RFn           1         264         TA         TA          Y
# 382           RFn           2         639         TA         TA          Y
# 1232          Unf           2         462         TA         TA          Y
# 1354          RFn           3         839         TA         TA          Y
# 331           RFn           1         308         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 733          165            0              0          0            0
# 382          144           53              0          0            0
# 1232           0            0              0          0            0
# 1354           0          184              0          0            0
# 331            0            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 733          0    NaN  GdWo        Shed      400       3    2009       WD
# 382          0    NaN   NaN         NaN        0       4    2007       WD
# 1232         0    NaN   NaN         NaN        0       3    2007       WD
# 1354         0    NaN   NaN         NaN        0       6    2008       WD
# 331          0    NaN   NaN         NaN        0       8    2007       WD
#
#      SaleCondition
# 733         Normal
# 382         Normal
# 1232        Normal
# 1354        Normal
# 331         Normal

# %%
cat_cols = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 
 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
            'Foundation',
'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'MiscFeature', 'SaleType', 
           
           'SaleCondition', 'Fence']

# %%
from category_encoders import OneHotEncoder
cat_encoder = OneHotEncoder(cols=cat_cols, drop_invariant=True, handle_missing=0)
Xtr = cat_encoder.fit_transform(Xtr)
Xval = cat_encoder.transform(Xval)

# %%
Xtr.head()
# Out:
#       MSSubClass  MSZoning_1  MSZoning_2  MSZoning_3  MSZoning_4  MSZoning_5  \
# 733           20           1           0           0           0           0
# 382           60           1           0           0           0           0
# 1232          90           1           0           0           0           0
# 1354          60           1           0           0           0           0
# 331           20           1           0           0           0           0
#
#       LotFrontage  LotArea  Street_1  Street_2  Alley_1  Alley_2  Alley_3  \
# 733          80.0    10000         1         0        1        0        0
# 382          79.0     9245         1         0        1        0        0
# 1232         70.0     9842         1         0        1        0        0
# 1354          NaN    10316         1         0        1        0        0
# 331          70.0     8176         1         0        1        0        0
#
#       LotShape_1  LotShape_2  LotShape_3  LotShape_4  LandContour_1  \
# 733            1           0           0           0              1
# 382            0           1           0           0              1
# 1232           1           0           0           0              1
# 1354           0           1           0           0              1
# 331            1           0           0           0              1
#
#       LandContour_2  LandContour_3  LandContour_4  LotConfig_1  LotConfig_2  \
# 733               0              0              0            1            0
# 382               0              0              0            0            1
# 1232              0              0              0            0            0
# 1354              0              0              0            0            1
# 331               0              0              0            0            1
#
#       LotConfig_3  LotConfig_4  LandSlope_1  LandSlope_2  LandSlope_3  \
# 733             0            0            1            0            0
# 382             0            0            1            0            0
# 1232            1            0            1            0            0
# 1354            0            0            1            0            0
# 331             0            0            1            0            0
#
#       Neighborhood_1  Neighborhood_2  Neighborhood_3  Neighborhood_4  \
# 733                1               0               0               0
# 382                0               1               0               0
# 1232               0               0               1               0
# 1354               0               1               0               0
# 331                0               0               1               0
#
#       Neighborhood_5  Neighborhood_6  Neighborhood_7  Neighborhood_8  \
# 733                0               0               0               0
# 382                0               0               0               0
# 1232               0               0               0               0
# 1354               0               0               0               0
# 331                0               0               0               0
#
#       Neighborhood_9  Neighborhood_10  Neighborhood_11  Neighborhood_12  ...  \
# 733                0                0                0                0  ...
# 382                0                0                0                0  ...
# 1232               0                0                0                0  ...
# 1354               0                0                0                0  ...
# 331                0                0                0                0  ...
#
#       GarageCond_4  GarageCond_5  PavedDrive_1  PavedDrive_2  PavedDrive_3  \
# 733              0             0             1             0             0
# 382              0             0             1             0             0
# 1232             0             0             1             0             0
# 1354             0             0             1             0             0
# 331              0             0             1             0             0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 733          165            0              0          0            0
# 382          144           53              0          0            0
# 1232           0            0              0          0            0
# 1354           0          184              0          0            0
# 331            0            0              0          0            0
#
#       PoolArea  PoolQC_1  PoolQC_2  PoolQC_3  Fence_1  Fence_2  Fence_3  \
# 733          0         1         0         0        1        0        0
# 382          0         1         0         0        0        1        0
# 1232         0         1         0         0        0        1        0
# 1354         0         1         0         0        0        1        0
# 331          0         1         0         0        0        1        0
#
#       Fence_4  Fence_5  MiscFeature_1  MiscFeature_2  MiscFeature_3  \
# 733         0        0              1              0              0
# 382         0        0              0              1              0
# 1232        0        0              0              1              0
# 1354        0        0              0              1              0
# 331         0        0              0              1              0
#
#       MiscFeature_4  MiscVal  MoSold  YrSold  SaleType_1  SaleType_2  \
# 733               0      400       3    2009           1           0
# 382               0        0       4    2007           1           0
# 1232              0        0       3    2007           1           0
# 1354              0        0       6    2008           1           0
# 331               0        0       8    2007           1           0
#
#       SaleType_3  SaleType_4  SaleType_5  SaleType_6  SaleType_7  SaleType_8  \
# 733            0           0           0           0           0           0
# 382            0           0           0           0           0           0
# 1232           0           0           0           0           0           0
# 1354           0           0           0           0           0           0
# 331            0           0           0           0           0           0
#
#       SaleCondition_1  SaleCondition_2  SaleCondition_3  SaleCondition_4  \
# 733                 1                0                0                0
# 382                 1                0                0                0
# 1232                1                0                0                0
# 1354                1                0                0                0
# 331                 1                0                0                0
#
#       SaleCondition_5  SaleCondition_6
# 733                 0                0
# 382                 0                0
# 1232                0                0
# 1354                0                0
# 331                 0                0
#
# [5 rows x 285 columns]

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
Xtr = imputer.fit_transform(Xtr)
Xval = imputer.transform(Xval)

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
Xtr = scaler.fit_transform(Xtr)
Xval = scaler.transform(Xval)

# %%
Xtr
# Out:
# array([[0.10526316, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.31578947, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.47368421, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.47368421, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.63157895, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.31578947, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
ytr = ytr.values
yval = yval.values

# %%
from tensorflow import keras as tfk

# %%
#hid = tfk.layers.Dropout(0.5)(hid)

Python para zumbis

# %%
tf.random.set_seed(2)

inp = tfk.layers.Input((Xtr.shape[1], ))

hid1 = tfk.layers.Dense(100, activation='relu')(inp)

drop = tfk.layers.Dropout(0.5)(hid1)

hid2 = tfk.layers.Dense(18, activation='relu')(drop)

out = tfk.layers.Dense(1, activation='relu')(hid2)

mdl = tfk.Model(inp, out)
mdl.compile(loss='msle', optimizer='adam')
mdl.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 285)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               28600
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 18)                1818
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 19
# =================================================================
# Total params: 30,437
# Trainable params: 30,437
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 0.0144

# %%
np.sqrt(144)
# Out:
# 12.0

# %%
es = tfk.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.1, patience=10, mode='min', restore_best_weights=True
)

# %%
mdl.fit(Xtr, ytr, validation_data=(Xval, yval), epochs=1000, shuffle=True, batch_size=1, callbacks=[es])
# Out:
# Train on 730 samples, validate on 730 samples
# Epoch 1/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 57.5609 - val_loss: 29.2098
# Epoch 2/1000
# 730/730 [==============================] - 2s 3ms/sample - loss: 21.2750 - val_loss: 15.4080
# Epoch 3/1000
# 730/730 [==============================] - 2s 3ms/sample - loss: 12.4860 - val_loss: 9.7023
# Epoch 4/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 8.1688 - val_loss: 6.4325
# Epoch 5/1000
# 730/730 [==============================] - 2s 3ms/sample - loss: 5.5054 - val_loss: 4.2986
# Epoch 6/1000
# 730/730 [==============================] - 2s 3ms/sample - loss: 3.6914 - val_loss: 2.8503
# Epoch 7/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 2.4735 - val_loss: 1.8431
# Epoch 8/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 1.6003 - val_loss: 1.1485
# Epoch 9/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.9953 - val_loss: 0.6937
# Epoch 10/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.6165 - val_loss: 0.4078
# Epoch 11/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.3883 - val_loss: 0.2426
# Epoch 12/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.2549 - val_loss: 0.1609
# Epoch 13/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1968 - val_loss: 0.1250
# Epoch 14/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1771 - val_loss: 0.1119
# Epoch 15/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1563 - val_loss: 0.1061
# Epoch 16/1000
# 730/730 [==============================] - 3s 5ms/sample - loss: 0.1511 - val_loss: 0.1004
# Epoch 17/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1492 - val_loss: 0.0936
# Epoch 18/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1387 - val_loss: 0.0862
# Epoch 19/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1208 - val_loss: 0.0802
# Epoch 20/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1081 - val_loss: 0.0739
# Epoch 21/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.1128 - val_loss: 0.0667
# Epoch 22/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.0959 - val_loss: 0.0603
# Epoch 23/1000
# 730/730 [==============================] - 3s 4ms/sample - loss: 0.0856 - val_loss: 0.0561

# %%
p = mdl.predict(Xval)
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error(yval, p))
# Out:
# 0.35353698001324463
